# %%
import matplotlib.pyplot as plt
import numpy as np

# Create grid points
x = np.linspace(0, 1, 11)  # 10 intervals from 0 to 1
y = np.linspace(0, 1, 11)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot lattice
plt.scatter(X, Y, color='black', marker='o')
plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create grid points
x = np.linspace(0, 1, 11)  # 10 intervals from 0 to 1
y = np.linspace(0, 1, 11)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot lattice
plt.scatter(X, Y, color='black')
plt.plot(x, x, color='red', marker='x', linestyle='', markersize=8)
plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice')
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
plt.scatter(X, Y, color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if x[i] == y[j]:  # Check if x and y coordinates are equal
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black', marker='o')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black')
        elif (x[i], y[j]) == (0, 0) or (x[i], y[j]) == (1, 1):  # Check for points (0,0) and (1,1)
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black')
        elif np.isclose(x[i], 0, atol=1e-8) and np.isclose(y[j], 0, atol=1e-8):  # Check for point (0,0)
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        elif np.isclose(x[i], 1, atol=1e-8) and np.isclose(y[j], 1, atol=1e-8):  # Check for point (1,1)
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='dashed', marker='o')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black', linestyle='dotted')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')


# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Add legend
plt.legend(legend_handles, legend_labels)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='black', facecolors='none', edgecolors='black', linestyle='dotted')
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='black', linestyle='dotted')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker', 'Dotted Marker']

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.grid(False)

# Add legend
plt.legend(legend_handles, legend_labels)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='black', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Lattice of 10x10 Grid Points')
plt.axis('off')  # Remove the axis box

# Add legend
plt.legend(legend_handles, legend_labels, loc='lower right')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(False)

# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='upper center', ncol=3)
plt.setp(legend.get_title(), fontsize='medium')

# Adjust spacing between legend and plot
plt.subplots_adjust(top=0.85)

# Remove the title
plt.title('')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(False)
plt.axis('off')

# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3)
plt.setp(legend.get_title(), fontsize='medium')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('X')
plt.ylabel('Y')
plt.xticks(np.arange(0.1, 1.1, 0.1))
plt.yticks(np.arange(0.1, 1.1, 0.1))
plt.grid(False)
plt.axis('off')

# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3)
plt.setp(legend.get_title(), fontsize='medium')

plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0.0, 1.1, 0.1)
y = np.arange(0.0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='black', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Live grid points', 'Singularity', 'Excision surface points']

# Set plot properties
plt.xlabel('x')
plt.ylabel('t')
plt.xticks(np.arange(0.0, 1.1, 0.1))
plt.yticks(np.arange(0.0, 1.1, 0.1))
plt.grid(True)


# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=3)
plt.setp(legend.get_title(), fontsize=11)


plt.style.use("default")

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('t')
plt.ylabel('x')
plt.xticks(np.arange(0.1, 1.1, 0.1))
plt.yticks(np.arange(0.1, 1.1, 0.1))
plt.grid(True)

# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='center left', bbox_to_anchor=(1.02, 0.5), ncol=1)
plt.setp(legend.get_title(), fontsize='medium')

plt.grid(True)

# Set the aspect ratio to equal, making the plot a square
plt.axis('equal')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Generate grid points
x = np.arange(0, 1.1, 0.1)
y = np.arange(0, 1.1, 0.1)

# Create meshgrid
X, Y = np.meshgrid(x, y)

# Plot grid points
for i in range(len(x)):
    for j in range(len(y)):
        if np.isclose(x[i], y[j], atol=1e-8):  # Check if x and y coordinates are close
            plt.scatter(X[i, j], Y[i, j], color='red', marker='X')
        elif np.isclose(y[j], x[i] + 0.2, atol=1e-8) or np.isclose(y[j], x[i] - 0.2, atol=1e-8):
            plt.scatter(X[i, j], Y[i, j], color='white', facecolors='none', edgecolors='black', linestyle='None', marker='o')
        elif np.isclose(y[j], x[i] + 0.1, atol=1e-8) or np.isclose(y[j], x[i] - 0.1, atol=1e-8):
            continue  # Skip plotting the dotted markers
        else:
            plt.scatter(X[i, j], Y[i, j], color='black')

# Create custom legend handles and labels
legend_handles = [
    Line2D([], [], color='black', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black'),
    Line2D([], [], color='red', marker='X', linestyle='None'),
    Line2D([], [], color='white', marker='o', linestyle='None', markerfacecolor='none', markeredgecolor='black')
]

legend_labels = ['Solid Marker', 'X Marker', 'Hollow Marker']

# Set plot properties
plt.xlabel('t')
plt.ylabel('x')
plt.xticks(np.arange(0.0, 1.1, 0.1))
plt.yticks(np.arange(0.1, 1.1, 0.1))
plt.grid(True)

# Add legend
legend = plt.legend(legend_handles, legend_labels, loc='center left', bbox_to_anchor=(1.02, 0.5), ncol=1)
plt.setp(legend.get_title(), fontsize='medium')

plt.grid(True)

# Set the aspect ratio to equal, making the plot a square
plt.axis('equal')

# Remove padding on the left and right
plt.subplots_adjust(left=0, right=1)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.Polygon(vertices, closed=True, facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Shaded Polygon')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.Polygon(vertices, closed=True, facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Generate random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not polygon.get_path().contains_point((x, y)):
        points.append((x, y))

# Scatter the random points
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Shaded Polygon with Random Points')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Shaded Polygon with Hollow Markers on Boundary')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2)

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Shaded Polygon with Hollow Markers on Boundary')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2)

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4)

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Shaded Polygon with Hollow Markers on Boundary')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2)

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4)

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5)

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and title
plt.xlabel('x')
plt.ylabel('t')
#plt.title('Shaded Polygon with Hollow Markers on Boundary')

plt.style.use("default")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Black Markers')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Hollow Markers')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Red Line')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Blue Markers')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
ax.legend(loc='upper left')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Domain Training Data')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary Training Data')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Red Line')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Blue Markers')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=4)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Black Markers')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Hollow Markers')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Red Line')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Blue Markers')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=1)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Black Markers')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Hollow Markers')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Red Line')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Blue Markers')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=2)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Domain training points')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary training points')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Singularity')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Regulating sparse data')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)


ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, fontsize = 11)

# Set labels and title
plt.xlabel('x')
plt.ylabel('t')
#plt.title('Shaded Polygon with Hollow Markers on Boundary')

plt.style.use("default")



# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Domain training points')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary training points')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)



# Scatter points along y = 0
x_boundary = np.linspace(0, 1.1, num=30, endpoint=False)
y_boundary = np.zeros(30) + 0.005
ax.scatter(x_boundary, y_boundary, color='blue', zorder=5,)



# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Singularity')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Known data')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)


ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, fontsize = 11)

# Set labels and title
plt.xlabel('x')
plt.ylabel('t')
#plt.title('Shaded Polygon with Hollow Markers on Boundary')

plt.style.use("default")



# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='black', edgecolors='black', zorder=2, label='Domain training points')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary training points')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary training points')

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Singularity')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Regulating sparse data')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2, fontsize=11)

# Set labels and title
plt.xlabel('x')
plt.ylabel('t')

plt.style.use("default")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.path import Path
import numpy as np

# Create a figure and axis
fig, ax = plt.subplots()

# Define the vertices of the polygon
vertices = [(0, 0), (0, 0.2), (0.8, 1), (1, 1), (1, 0.8), (0.2, 0), (0, 0)]

# Create a polygon patch
polygon = patches.PathPatch(Path(vertices), facecolor='lightgray')

# Add the polygon patch to the axis
ax.add_patch(polygon)

# Scatter random points outside the polygon
num_points = 100
points = []
while len(points) < num_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        points.append((x, y))

# Scatter the random points with solid markers
x_coords, y_coords = zip(*points)
ax.scatter(x_coords, y_coords, color='black', facecolors='none', edgecolors='black', zorder=2, label='Domain training points')

# Scatter points along y = x + 0.2 with hollow markers
x_boundary = np.linspace(0, 0.8, num=20, endpoint=False)
y_boundary = x_boundary + 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3, label='Boundary training points')

# Scatter points along y = x - 0.2 with hollow markers
x_boundary = np.linspace(0.2, 1, num=20, endpoint=False)
y_boundary = x_boundary - 0.2
ax.scatter(x_boundary, y_boundary, color='black', facecolors='none', edgecolors='black', zorder=3)

# Plot the red line at y = x
x_line = np.linspace(0, 1, 100)
y_line = x_line
ax.plot(x_line, y_line, color='red', linewidth=2, zorder=4, label='Singularity')

# Scatter 5 blue points outside the polygon
num_blue_points = 5
blue_points = []
while len(blue_points) < num_blue_points:
    x = np.random.uniform(0, 1)
    y = np.random.uniform(0, 1)
    if not Path(vertices).contains_point((x, y)):
        blue_points.append((x, y))

blue_x_coords, blue_y_coords = zip(*blue_points)
ax.scatter(blue_x_coords, blue_y_coords, color='blue', zorder=5, label='Regulating sparse data')

# Set the limits of the plot to form a 1.0 by 1.0 box
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Set labels and legend
plt.xlabel('X')
plt.ylabel('Y')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=2)

# Show the plot
plt.show()
